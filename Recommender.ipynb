# %%
import pandas as pd
import numpy as np

# %%
df_titles = pd.read_csv('Movie_Id_Titles')

# %%
df_titles
# Out:
#       item_id                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
df_titles.isnull().sum()
# Out:
# item_id    0
# title      0
# dtype: int64

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)

# %%
df
# Out:
#         user_id  item_id  rating  timestamp
# 0             0       50       5  881250949
# 1             0      172       5  881250949
# 2             0      133       1  881250949
# 3           196      242       3  881250949
# 4           186      302       3  891717742
# ...         ...      ...     ...        ...
# 99998       880      476       3  880175444
# 99999       716      204       5  879795543
# 100000      276     1090       1  874795795
# 100001       13      225       2  882399156
# 100002       12      203       3  879959583
#
# [100003 rows x 4 columns]

# %%
df = pd.merge(df,df_titles,on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby('title').groups
# Out:
# {"'Til There Was You (1997)": Int64Index([97446, 97447, 97448, 97449, 97450, 97451, 97452, 97453, 97454], dtype='int64'),
#  '1-900 (1994)': Int64Index([98318, 98319, 98320, 98321, 98322], dtype='int64'),
#  '101 Dalmatians (1996)': Int64Index([59871, 59872, 59873, 59874, 59875, 59876, 59877, 59878, 59879,
#              59880,
#              ...
#              59970, 59971, 59972, 59973, 59974, 59975, 59976, 59977, 59978,
#              59979],
#             dtype='int64', length=109),
#  '12 Angry Men (1957)': Int64Index([30013, 30014, 30015, 30016, 30017, 30018, 30019, 30020, 30021,
#              30022,
#              ...
#              30128, 30129, 30130, 30131, 30132, 30133, 30134, 30135, 30136,
#              30137],
#             dtype='int64', length=125),
#  '187 (1997)': Int64Index([90095, 90096, 90097, 90098, 90099, 90100, 90101, 90102, 90103,
#              90104, 90105, 90106, 90107, 90108, 90109, 90110, 90111, 90112,
# ...

# %%
df.groupby('title')['rating'].groups
# Out:
# {"'Til There Was You (1997)": Int64Index([97446, 97447, 97448, 97449, 97450, 97451, 97452, 97453, 97454], dtype='int64'),
#  '1-900 (1994)': Int64Index([98318, 98319, 98320, 98321, 98322], dtype='int64'),
#  '101 Dalmatians (1996)': Int64Index([59871, 59872, 59873, 59874, 59875, 59876, 59877, 59878, 59879,
#              59880,
#              ...
#              59970, 59971, 59972, 59973, 59974, 59975, 59976, 59977, 59978,
#              59979],
#             dtype='int64', length=109),
#  '12 Angry Men (1957)': Int64Index([30013, 30014, 30015, 30016, 30017, 30018, 30019, 30020, 30021,
#              30022,
#              ...
#              30128, 30129, 30130, 30131, 30132, 30133, 30134, 30135, 30136,
#              30137],
#             dtype='int64', length=125),
#  '187 (1997)': Int64Index([90095, 90096, 90097, 90098, 90099, 90100, 90101, 90102, 90103,
#              90104, 90105, 90106, 90107, 90108, 90109, 90110, 90111, 90112,
# ...

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=True).head()
# Out:
# title
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# Butterfly Kiss (1995)                           1.0
# Daens (1992)                                    1.0
# JLG/JLG - autoportrait de décembre (1994)       1.0
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
df.groupby('title')['rating']

# %%
df['title'].count()
# Out:
# 100003

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())

# %%
type('rating')
# Out:
# str

# %%
ratings
# Out:
#                                          rating  num of ratings
# title
# 'Til There Was You (1997)              2.333333               9
# 1-900 (1994)                           2.600000               5
# 101 Dalmatians (1996)                  2.908257             109
# 12 Angry Men (1957)                    4.344000             125
# 187 (1997)                             3.024390              41
# ...                                         ...             ...
# Young Guns II (1990)                   2.772727              44
# Young Poisoner's Handbook, The (1995)  3.341463              41
# Zeus and Roxanne (1997)                2.166667               6
# unknown                                3.444444               9
# Á köldum klaka (Cold Fever) (1994)     3.000000               1
#
# [1664 rows x 2 columns]

# %%
df_0 = pd.DataFrame(ratings)

# %%
df_0
# Out:
#                                          rating  num of ratings
# title
# 'Til There Was You (1997)              2.333333               9
# 1-900 (1994)                           2.600000               5
# 101 Dalmatians (1996)                  2.908257             109
# 12 Angry Men (1957)                    4.344000             125
# 187 (1997)                             3.024390              41
# ...                                         ...             ...
# Young Guns II (1990)                   2.772727              44
# Young Poisoner's Handbook, The (1995)  3.341463              41
# Zeus and Roxanne (1997)                2.166667               6
# unknown                                3.444444               9
# Á köldum klaka (Cold Fever) (1994)     3.000000               1
#
# [1664 rows x 2 columns]

# %%
type(df_0)
# Out:
# pandas.core.frame.DataFrame

# %%
df_0
# Out:
#                                          rating  num of ratings
# title
# 'Til There Was You (1997)              2.333333               9
# 1-900 (1994)                           2.600000               5
# 101 Dalmatians (1996)                  2.908257             109
# 12 Angry Men (1957)                    4.344000             125
# 187 (1997)                             3.024390              41
# ...                                         ...             ...
# Young Guns II (1990)                   2.772727              44
# Young Poisoner's Handbook, The (1995)  3.341463              41
# Zeus and Roxanne (1997)                2.166667               6
# unknown                                3.444444               9
# Á köldum klaka (Cold Fever) (1994)     3.000000               1
#
# [1664 rows x 2 columns]

# %%
df_1 = df_0.reset_index()

# %%
df_1
# Out:
#                                       title    rating  num of ratings
# 0                 'Til There Was You (1997)  2.333333               9
# 1                              1-900 (1994)  2.600000               5
# 2                     101 Dalmatians (1996)  2.908257             109
# 3                       12 Angry Men (1957)  4.344000             125
# 4                                187 (1997)  3.024390              41
# ...                                     ...       ...             ...
# 1659                   Young Guns II (1990)  2.772727              44
# 1660  Young Poisoner's Handbook, The (1995)  3.341463              41
# 1661                Zeus and Roxanne (1997)  2.166667               6
# 1662                                unknown  3.444444               9
# 1663     Á köldum klaka (Cold Fever) (1994)  3.000000               1
#
# [1664 rows x 3 columns]

# %%
df_1_upper = df_1.rename(columns={'title':'TITLE','rating':'RATINGS','num of ratings':'NUM OF RATINGS'})

# %%
df_1_upper
# Out:
#                                       TITLE   RATINGS  NUM OF RATINGS
# 0                 'Til There Was You (1997)  2.333333               9
# 1                              1-900 (1994)  2.600000               5
# 2                     101 Dalmatians (1996)  2.908257             109
# 3                       12 Angry Men (1957)  4.344000             125
# 4                                187 (1997)  3.024390              41
# ...                                     ...       ...             ...
# 1659                   Young Guns II (1990)  2.772727              44
# 1660  Young Poisoner's Handbook, The (1995)  3.341463              41
# 1661                Zeus and Roxanne (1997)  2.166667               6
# 1662                                unknown  3.444444               9
# 1663     Á köldum klaka (Cold Fever) (1994)  3.000000               1
#
# [1664 rows x 3 columns]

# %%
df_1_upper['NUM OF RATINGS'].min()
# Out:
# 1

# %%
https://stackoverflow.com/questions/48226983/unable-to-set-column-names-after-a-group-by-pandas

# %%
#plt.figure(figsize=(10,4))
df_1_upper['NUM OF RATINGS'].hist(bins=100)

# %%
plt.figure(figsize=(10,4))
df_1_upper['RATINGS'].hist(bins=70)

# %%
sns.jointplot(x='RATINGS', y='NUM OF RATINGS', data=df_1_upper, alpha=0.5)

# %%
#pearson

# %%
#Recommending Similar Movies¶

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')

# %%
moviemat
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                  rating  num of ratings
# title
# Star Wars (1977)               4.359589             584
# Contact (1997)                 3.803536             509
# Fargo (1996)                   4.155512             508
# Return of the Jedi (1983)      4.007890             507
# Liar Liar (1997)               3.156701             485
# English Patient, The (1996)    3.656965             481
# Scream (1996)                  3.441423             478
# Toy Story (1995)               3.878319             452
# Air Force One (1997)           3.631090             431
# Independence Day (ID4) (1996)  3.438228             429

# %%
starwars_user_ratings = moviemat['Star Wars (1977)']
liarliar_user_ratings = moviemat['Liar Liar (1997)']

# %%
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
moviemat.corrwith(starwars_user_ratings)
# Out:
# C:\Users\Zng\anaconda3\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\Zng\anaconda3\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# Á köldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# C:\Users\Zng\anaconda3\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\Zng\anaconda3\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Hollow Reed (1996)                                          1.0
# Stripes (1981)                                              1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Safe Passage (1994)                                         1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0
# Line King: Al Hirschfeld, The (1996)                        1.0
# Hurricane Streets (1998)                                    1.0
# Good Man in Africa, A (1994)                                1.0
# Scarlet Letter, The (1926)                                  1.0

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])

# %%
corr_starwars
# Out:
#                                        Correlation  num of ratings
# title
# 'Til There Was You (1997)                 0.872872               9
# 1-900 (1994)                             -0.645497               5
# 101 Dalmatians (1996)                     0.211132             109
# 12 Angry Men (1957)                       0.184289             125
# 187 (1997)                                0.027398              41
# ...                                            ...             ...
# Young Guns (1988)                         0.186377             101
# Young Guns II (1990)                      0.228615              44
# Young Poisoner's Handbook, The (1995)    -0.007374              41
# Zeus and Roxanne (1997)                   0.818182               6
# unknown                                   0.723123               9
#
# [1410 rows x 2 columns]

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130

# %%
df_ratings = pd.DataFrame(ratings)

# %%
df_ratings
# Out:
#                                          rating  num of ratings
# title
# 'Til There Was You (1997)              2.333333               9
# 1-900 (1994)                           2.600000               5
# 101 Dalmatians (1996)                  2.908257             109
# 12 Angry Men (1957)                    4.344000             125
# 187 (1997)                             3.024390              41
# ...                                         ...             ...
# Young Guns II (1990)                   2.772727              44
# Young Poisoner's Handbook, The (1995)  3.341463              41
# Zeus and Roxanne (1997)                2.166667               6
# unknown                                3.444444               9
# Á köldum klaka (Cold Fever) (1994)     3.000000               1
#
# [1664 rows x 2 columns]

# %%
#df_ratings.rename(columns={'title':'titulo','rating':'nota','num of ratings':'numero de notas'})

# %%
####################################

# %%
ratings['num of ratings']
# Out:
# title
# 'Til There Was You (1997)                  9
# 1-900 (1994)                               5
# 101 Dalmatians (1996)                    109
# 12 Angry Men (1957)                      125
# 187 (1997)                                41
#                                         ...
# Young Guns II (1990)                      44
# Young Poisoner's Handbook, The (1995)     41
# Zeus and Roxanne (1997)                    6
# unknown                                    9
# Á köldum klaka (Cold Fever) (1994)         1
# Name: num of ratings, Length: 1664, dtype: int64

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)

# %%
new = pd.DataFrame({'Primary Type':list('aaabbb'),
                   'Year':[2001,2001,2002,2002,2002,2002],
                   '_id':[7,8,9,4,2,3],
                   'Date':[1,3,5,7,1,0]})

# %%
new
# Out:
#   Primary Type  Year  _id  Date
# 0            a  2001    7     1
# 1            a  2001    8     3
# 2            a  2002    9     5
# 3            b  2002    4     7
# 4            b  2002    2     1
# 5            b  2002    3     0

# %%
g = (new.groupby(['Primary Type', 'Year'])['_id'].count().reset_index(name="Count").reindex(columns=['Count', 'Primary Type', 'Year']))

# %%
g

# %%
g = (new.groupby(['Primary Type', 'Year'])['_id'].count())

# %%
g
# Out:
# Primary Type  Year
# a             2001    2
#               2002    1
# b             2002    3
# Name: _id, dtype: int64

# %%
g = (new.groupby(['Primary Type', 'Year'])['_id'].count().reset_index(name="Count"))

# %%
g
# Out:
#   Primary Type  Year  Count
# 0            a  2001      2
# 1            a  2002      1
# 2            b  2002      3

# %%
.reindex(columns=['Count', 'Primary Type', 'Year']))
